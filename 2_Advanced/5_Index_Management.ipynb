# %%
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df.sample(5)
# Out:
#              job_title_short  \
# 740245         Data Engineer
# 707118         Data Engineer
# 132905        Data Scientist
# 473900         Data Engineer
# 757775  Senior Data Engineer
#
#                                                 job_title  \
# 740245                            Principal Data Engineer
# 707118              Data Engineer - Full-time / Part-time
# 132905                                 Sr. Data Scientist
# 473900                                  ETL Data Engineer
# 757775  Senior Data Architect/Data Engineer - Governme...
#
#                   job_location          job_via job_schedule_type  \
# 740245  Pyrmont NSW, Australia  via Trabajo.org         Full-time
# 707118          Broomfield, CO     via Snagajob         Full-time
# 132905         Santa Clara, CA        via BeBee         Full-time
# 473900     Toronto, ON, Canada       via Indeed              None
# 757775                Anywhere     via LinkedIn        Contractor
#
#         job_work_from_home            search_location     job_posted_date  \
# 740245               False                  Australia 2023-08-03 21:11:02
# 707118               False                    Georgia 2023-08-14 02:34:26
# 132905               False  California, United States 2023-04-01 08:03:30
# 473900               False                     Canada 2023-04-21 14:34:00
# 757775                True                     Canada 2023-07-04 20:10:51
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 740245                   True                 False      Australia
# 707118                  False                  True  United States
# 132905                  False                 False  United States
# 473900                  False                 False         Canada
# 757775                  False                 False         Canada
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 740245        None              NaN              NaN
# 707118        hour              NaN             56.0
# 132905        None              NaN              NaN
# 473900        None              NaN              NaN
# 757775        None              NaN              NaN
#
#                               company_name  \
# 740245                        Domain Group
# 707118            ZOLL Medical Corporation
# 132905                 Laksan Technologies
# 473900                   Dawn InfoTek Inc.
# 757775  CORADIX Technology Consulting Ltd.
#
#                                                job_skills  \
# 740245  ['sql', 'python', 'aws', 'snowflake', 'bigquer...
# 707118  ['sql', 'python', 'aws', 'kafka', 'airflow', '...
# 132905                                         ['python']
# 473900  ['sql', 't-sql', 'python', 'sql server', 'azur...
# 757775  ['java', 'python', 'dynamodb', 'neo4j', 'aws',...
#
#                                           job_type_skills
# 740245  {'cloud': ['aws', 'snowflake', 'bigquery'], 'o...
# 707118  {'cloud': ['aws'], 'libraries': ['kafka', 'air...
# 132905                        {'programming': ['python']}
# 473900  {'analyst_tools': ['ssis', 'sharepoint', 'powe...
# 757775  {'cloud': ['aws'], 'databases': ['dynamodb', '...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name

# %%
df.index.name = 'job_index'
df.index.name
# Out:
# 'job_index'

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country']=='United States']
df_usa.reset_index(inplace=True)

# %%
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# 3       via LinkedIn                 Full-time               False
# 4   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 1     Texas, United States 2023-07-04 13:01:41                   True
# 2                  Georgia 2023-11-07 14:01:59                  False
# 3   Florida, United States 2023-03-27 13:18:18                  False
# 4  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 1              NaN   Southwest Research Institute
# 2              NaN                smart folks inc
# 3              NaN  Miracle Software Systems, Inc
# 4              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.set_index('job_index', inplace=True)

# %%
df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
median_pivot = df.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['median','max','min'])

# %%
median_pivot.sort_values(by=('median','salary_year_avg'))
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0        387460.0         16500.0
# Cloud Engineer                    90000.0        280000.0         42000.0
# Data Analyst                      90000.0        650000.0         25000.0
# Software Engineer                 99150.0        375000.0         28000.0
# Machine Learning Engineer        106415.0        325000.0         30000.0
# Senior Data Analyst              111175.0        425000.0         30000.0
# Data Engineer                    125000.0        525000.0         15000.0
# Data Scientist                   127500.0        960000.0         27000.0
# Senior Data Engineer             147500.0        425000.0         35000.0
# Senior Data Scientist            155500.0        890000.0         45000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             max             min
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0        387460.0         16500.0
# Cloud Engineer                    90000.0        280000.0         42000.0
# Data Analyst                      90000.0        650000.0         25000.0
# Data Engineer                    125000.0        525000.0         15000.0
# Data Scientist                   127500.0        960000.0         27000.0
# Machine Learning Engineer        106415.0        325000.0         30000.0
# Senior Data Analyst              111175.0        425000.0         30000.0
# Senior Data Engineer             147500.0        425000.0         35000.0
# Senior Data Scientist            155500.0        890000.0         45000.0
# Software Engineer                 99150.0        375000.0         28000.0
